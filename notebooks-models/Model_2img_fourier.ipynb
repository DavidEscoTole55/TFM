# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import cv2 as cv
import numpy as np
import os

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Rutas importantes
dataset_path = '/content/dataset/dataset'
models_path = '/content/drive/MyDrive/TFM/models'
img_type = 'fourier'
model_name = f'2Img_{img_type}_Tab'
# Out:
# Mounted at /content/drive

# %%
rm -rf "/content/dataset"

# %%
# !unzip "/content/drive/MyDrive/TFM/dataset.zip" -d "/content/dataset" > /dev/null 2>&1

# %%
# Ruta al dataset
data_dir= f'{dataset_path}/imagenes'

img_height, img_width = 20, 20

# Listar y cargar imágenes
image_array = []

def numeric_sort_key(filename,label):
    return int(os.path.splitext(filename)[0].replace(f"_{label}",""))  # Extrae el número del nombre antes del '.jpg'

for label in ["estrellas","galaxias"]:

    data_dir_label = data_dir + "/" + label

    file_names = sorted(os.listdir(data_dir_label), key= lambda x: numeric_sort_key(x,label))
    print(len(file_names))

    for fname in file_names:

        if fname.endswith(('.png', '.jpg', '.jpeg')):

          img_path = os.path.join(data_dir_label, fname)
          img = tf.keras.utils.load_img(img_path, target_size=(img_height, img_width))
          img_array = tf.keras.utils.img_to_array(img)
          image_array.append(img_array)

# Convertir a array de NumPy
X_images = np.array(image_array, dtype="float32") / 255.0



# Ruta al dataset
data_dir= f'{dataset_path}/imagenes_clean_{img_type}'

# Listar y cargar imágenes
image_array = []

def numeric_sort_key(filename,label):
    return int(os.path.splitext(filename)[0].replace(f"_{label}",""))  # Extrae el número del nombre antes del '.jpg'

for label in ["estrellas","galaxias"]:

    data_dir_label = data_dir + "/" + label

    file_names = sorted(os.listdir(data_dir_label), key= lambda x: numeric_sort_key(x,label))
    print(len(file_names))

    for fname in file_names:

        if fname.endswith(('.png', '.jpg', '.jpeg')):

          img_path = os.path.join(data_dir_label, fname)
          img = tf.keras.utils.load_img(img_path, target_size=(img_height, img_width))
          img_array = tf.keras.utils.img_to_array(img)
          image_array.append(img_array)

# Convertir a array de NumPy
X_images_processed = np.array(image_array, dtype="float32") / 255.0
# Out:
# 10000
# 10000
# 10000
# 10000

# %%
file_name_galaxias = f"galaxias_10000_extended.csv"
file_name_estrellas= f"estrellas_10000_extended.csv"

df_galaxias = pd.read_csv(f"{dataset_path}/fotometria/conformed/{file_name_galaxias}", index_col=False).sort_values("id",ascending=True)
df_estrellas = pd.read_csv(f"{dataset_path}/fotometria/conformed/{file_name_estrellas}", index_col=False).sort_values("id",ascending=True)

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df_all = pd.concat([df_estrellas,df_galaxias],axis=0).drop(["ra","dec","flags_r","id"], axis=1)

y = df_all["label"].values
# X_tabular = pd.DataFrame(scaler.fit_transform(df_all.drop(["label"],axis=1)),columns=df_all.drop(["label"],axis=1).columns)

X_tabular = scaler.fit_transform(df_all.drop(["label"],axis=1))

# %%
# Generar una permutación aleatoria
np.random.seed(15)
perm = np.random.permutation(len(y))

# Aplicar la misma permutación a ambos arrays
X_tabular_shuffled = X_tabular[perm]
X_images_shuffled = X_images[perm]
X_images_processed_shuffled = X_images_processed[perm]
y_shuffled = y[perm]

train_per = int(round(len(y)*0.7))
valid_per = int(round(len(y)*0.15))
test_per = int(round(len(y)*0.15))

X_train, y_train = [X_images_shuffled[:train_per], X_images_processed_shuffled[:train_per], X_tabular_shuffled[:train_per]], y_shuffled[:train_per]
X_valid, y_valid = [X_images_shuffled[train_per:train_per + valid_per], X_images_processed_shuffled[train_per:train_per + valid_per], X_tabular_shuffled[train_per:train_per + valid_per]], y_shuffled[train_per:train_per + valid_per]
X_test, y_test = [X_images_shuffled[train_per + valid_per:], X_images_processed_shuffled[train_per + valid_per:], X_tabular_shuffled[train_per + valid_per:]], y_shuffled[train_per + valid_per:]

# %%
from tensorflow.keras import layers, models, Input
from keras import regularizers, saving
from tensorflow.keras.optimizers import SGD, Nadam, Adam, AdamW, RMSprop
import tensorflow as tf


def convolutional_attention_block(input_tensor):
    """Atención espacial usando operaciones convolucionales"""

    # Asume que input_tensor tiene shape (None, H, W, C)
    @saving.register_keras_serializable()
    def channel_avg(x):
        return tf.reduce_mean(x, axis=3, keepdims=True)

    @saving.register_keras_serializable()
    def channel_max(x):
        return tf.reduce_max(x, axis=3, keepdims=True)

    @saving.register_keras_serializable()
    def output_shape(input_shape):
        return (input_shape[0], input_shape[1], input_shape[2], 1)

    avg_pool = layers.Lambda(channel_avg, output_shape=output_shape)(input_tensor)
    max_pool = layers.Lambda(channel_max, output_shape=output_shape)(input_tensor)

    # Concatenar y aplicar convolución
    concat = layers.Concatenate(axis=3)([avg_pool, max_pool])
    attention = layers.Conv2D(1, (7, 7), padding='same', activation='sigmoid')(concat)

    return layers.Multiply()([input_tensor, attention])

# Entrada 1: imágenes RGB
image_input = Input(shape=(img_height, img_width, 3), name='image_input')

# Data Augmentation
x = layers.RandomRotation(0.2)(image_input)
x = layers.RandomZoom(0.2)(x)
x = layers.RandomContrast(0.2)(x)
x = layers.RandomTranslation(0.2, 0.2)(x)


# Bloque 1 con atención
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = convolutional_attention_block(x)  # Atención aquí
x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2))(x)

# Bloque 2
x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = convolutional_attention_block(x)  # Atención aquí
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2))(x)

# Bloque 3
x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = convolutional_attention_block(x)  # Atención aquí
x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.GlobalAveragePooling2D()(x)


# Entrada 2: imágenes RGB
image_processed_input = Input(shape=(img_height, img_width, 3), name='image_processed_input')

# Data Augmentation
y = layers.RandomRotation(0.2)(image_processed_input)
y = layers.RandomZoom(0.2)(y)
y = layers.RandomContrast(0.2)(y)
y = layers.RandomTranslation(0.2, 0.2)(y)

# Bloque 1 con atención
y = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(y)
y = convolutional_attention_block(y)  # Atención aquí
y = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(y)
y = layers.BatchNormalization()(y)
y = layers.MaxPooling2D((2, 2))(y)

# Bloque 2
y = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(y)
y = convolutional_attention_block(y)  # Atención aquí
y = layers.BatchNormalization()(y)
y = layers.MaxPooling2D((2, 2))(y)

# Bloque 3
y = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(y)
y = convolutional_attention_block(y)  # Atención aquí
y = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(y)
y = layers.BatchNormalization()(y)
y = layers.GlobalAveragePooling2D()(y)

# Entrada 3: datos adicionales
numeric_input = Input(shape=(15,), name='numeric_input')
numeric_branch = layers.Dense(250, activation='relu')(numeric_input)

# Concatenación de salidas
combined = layers.concatenate([x, y, numeric_branch])

# Red densa final
z = layers.Dense(500, activation='relu')(combined)
z = layers.Dropout(0.4)(z)
z = layers.Dense(1000, activation='relu', kernel_regularizer=regularizers.L2(1e-4))(z)
z = layers.Dropout(0.5)(z)
z = layers.Dense(500, activation='relu', kernel_regularizer=regularizers.L2(1e-4))(z)
z = layers.Dropout(0.4)(z)
output = layers.Dense(1, activation='sigmoid')(z)

# Modelo completo
model = models.Model(inputs=[image_input, image_processed_input, numeric_input], outputs=output)

# Compilar
# optimizer = SGD(learning_rate=0.01, momentum=0.9)
# optimizer = Nadam()
optimizer = Adam(learning_rate=1e-3)
# optimizer = RMSprop(learning_rate=1e-5, rho=0.9, momentum=0.9)
# optimizer = AdamW(learning_rate=1e-4, weight_decay=1e-4)

model.compile(
    optimizer=optimizer,
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ image_input         │ (None, 20, 20, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ image_processed_in… │ (None, 20, 20, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_rotation_10  │ (None, 20, 20, 3) │          0 │ image_input[0][0] │
# │ (RandomRotation)    │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_rotation_11  │ (None, 20, 20, 3) │          0 │ image_processed_… │
# │ (RandomRotation)    │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_zoom_10      │ (None, 20, 20, 3) │          0 │ random_rotation_… │
# │ (RandomZoom)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_zoom_11      │ (None, 20, 20, 3) │          0 │ random_rotation_… │
# │ (RandomZoom)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_contrast_10  │ (None, 20, 20, 3) │          0 │ random_zoom_10[0… │
# │ (RandomContrast)    │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_contrast_11  │ (None, 20, 20, 3) │          0 │ random_zoom_11[0… │
# │ (RandomContrast)    │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_translation… │ (None, 20, 20, 3) │          0 │ random_contrast_… │
# │ (RandomTranslation) │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_translation… │ (None, 20, 20, 3) │          0 │ random_contrast_… │
# │ (RandomTranslation) │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_80 (Conv2D)  │ (None, 20, 20,    │        896 │ random_translati… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_88 (Conv2D)  │ (None, 20, 20,    │        896 │ random_translati… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_60 (Lambda)  │ (None, 20, 20, 1) │          0 │ conv2d_80[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_61 (Lambda)  │ (None, 20, 20, 1) │          0 │ conv2d_80[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_66 (Lambda)  │ (None, 20, 20, 1) │          0 │ conv2d_88[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_67 (Lambda)  │ (None, 20, 20, 1) │          0 │ conv2d_88[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_35      │ (None, 20, 20, 2) │          0 │ lambda_60[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_61[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_38      │ (None, 20, 20, 2) │          0 │ lambda_66[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_67[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_81 (Conv2D)  │ (None, 20, 20, 1) │         99 │ concatenate_35[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_89 (Conv2D)  │ (None, 20, 20, 1) │         99 │ concatenate_38[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_30         │ (None, 20, 20,    │          0 │ conv2d_80[0][0],  │
# │ (Multiply)          │ 32)               │            │ conv2d_81[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_33         │ (None, 20, 20,    │          0 │ conv2d_88[0][0],  │
# │ (Multiply)          │ 32)               │            │ conv2d_89[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_82 (Conv2D)  │ (None, 20, 20,    │     18,496 │ multiply_30[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_90 (Conv2D)  │ (None, 20, 20,    │     18,496 │ multiply_33[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 20,    │        256 │ conv2d_82[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 20,    │        256 │ conv2d_90[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_20    │ (None, 10, 10,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_22    │ (None, 10, 10,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_83 (Conv2D)  │ (None, 10, 10,    │     73,856 │ max_pooling2d_20… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_91 (Conv2D)  │ (None, 10, 10,    │     73,856 │ max_pooling2d_22… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_62 (Lambda)  │ (None, 10, 10, 1) │          0 │ conv2d_83[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_63 (Lambda)  │ (None, 10, 10, 1) │          0 │ conv2d_83[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_68 (Lambda)  │ (None, 10, 10, 1) │          0 │ conv2d_91[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_69 (Lambda)  │ (None, 10, 10, 1) │          0 │ conv2d_91[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_36      │ (None, 10, 10, 2) │          0 │ lambda_62[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_63[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_39      │ (None, 10, 10, 2) │          0 │ lambda_68[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_69[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_84 (Conv2D)  │ (None, 10, 10, 1) │         99 │ concatenate_36[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_92 (Conv2D)  │ (None, 10, 10, 1) │         99 │ concatenate_39[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_31         │ (None, 10, 10,    │          0 │ conv2d_83[0][0],  │
# │ (Multiply)          │ 128)              │            │ conv2d_84[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_34         │ (None, 10, 10,    │          0 │ conv2d_91[0][0],  │
# │ (Multiply)          │ 128)              │            │ conv2d_92[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 10,    │        512 │ multiply_31[0][0] │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 10,    │        512 │ multiply_34[0][0] │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_21    │ (None, 5, 5, 128) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_23    │ (None, 5, 5, 128) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_85 (Conv2D)  │ (None, 5, 5, 256) │    295,168 │ max_pooling2d_21… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_93 (Conv2D)  │ (None, 5, 5, 256) │    295,168 │ max_pooling2d_23… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_64 (Lambda)  │ (None, 5, 5, 1)   │          0 │ conv2d_85[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_65 (Lambda)  │ (None, 5, 5, 1)   │          0 │ conv2d_85[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_70 (Lambda)  │ (None, 5, 5, 1)   │          0 │ conv2d_93[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_71 (Lambda)  │ (None, 5, 5, 1)   │          0 │ conv2d_93[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_37      │ (None, 5, 5, 2)   │          0 │ lambda_64[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_65[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_40      │ (None, 5, 5, 2)   │          0 │ lambda_70[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_71[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_86 (Conv2D)  │ (None, 5, 5, 1)   │         99 │ concatenate_37[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_94 (Conv2D)  │ (None, 5, 5, 1)   │         99 │ concatenate_40[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_32         │ (None, 5, 5, 256) │          0 │ conv2d_85[0][0],  │
# │ (Multiply)          │                   │            │ conv2d_86[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_35         │ (None, 5, 5, 256) │          0 │ conv2d_93[0][0],  │
# │ (Multiply)          │                   │            │ conv2d_94[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_87 (Conv2D)  │ (None, 5, 5, 128) │    295,040 │ multiply_32[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_95 (Conv2D)  │ (None, 5, 5, 128) │    295,040 │ multiply_35[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 5, 5, 128) │        512 │ conv2d_87[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 5, 5, 128) │        512 │ conv2d_95[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ numeric_input       │ (None, 15)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_25 (Dense)    │ (None, 250)       │      4,000 │ numeric_input[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_41      │ (None, 506)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_average_p… │
# │                     │                   │            │ dense_25[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_26 (Dense)    │ (None, 500)       │    253,500 │ concatenate_41[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 500)       │          0 │ dense_26[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_27 (Dense)    │ (None, 1000)      │    501,000 │ dropout_15[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 1000)      │          0 │ dense_27[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_28 (Dense)    │ (None, 500)       │    500,500 │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 500)       │          0 │ dense_28[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_29 (Dense)    │ (None, 1)         │        501 │ dropout_17[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,629,567 (10.03 MB)
#  Trainable params: 2,628,287 (10.03 MB)
#  Non-trainable params: 1,280 (5.00 KB)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor='val_accuracy',      # Métrica a monitorear (puede ser 'val_accuracy', 'val_auc', etc.)
    patience=10,              # Número de epochs sin mejora antes de detener
    restore_best_weights=True,  # Restaura los pesos del mejor epoch
    verbose=1                # Muestra un mensaje cuando se detiene
)

lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)

history = model.fit(X_train, y_train, epochs=100, batch_size=50, validation_data=(X_valid, y_valid), callbacks=[lr_scheduler,early_stopping])

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Datos Tabulares & Imágenes Originales & Imágenes Fourier')
plt.ylabel('Pérdida')
plt.xlabel('Época')
plt.legend(['Entto', 'Val'], loc='upper left')
plt.show()

model.save(f"{models_path}/{model_name}.keras")
# Out:
# Epoch 1/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 17s 25ms/step - accuracy: 0.7162 - auc_5: 0.7953 - loss: 0.6567 - precision_5: 0.6893 - recall_5: 0.7556 - val_accuracy: 0.5037 - val_auc_5: 0.6391 - val_loss: 1.4749 - val_precision_5: 0.5015 - val_recall_5: 1.0000 - learning_rate: 0.0010
# Epoch 2/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.7927 - auc_5: 0.8850 - loss: 0.4963 - precision_5: 0.7876 - recall_5: 0.8052 - val_accuracy: 0.8510 - val_auc_5: 0.9563 - val_loss: 0.3882 - val_precision_5: 0.8001 - val_recall_5: 0.9352 - learning_rate: 0.0010
# Epoch 3/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.8347 - auc_5: 0.9229 - loss: 0.3964 - precision_5: 0.8633 - recall_5: 0.7997 - val_accuracy: 0.8970 - val_auc_5: 0.9650 - val_loss: 0.3208 - val_precision_5: 0.8883 - val_recall_5: 0.9079 - learning_rate: 0.0010
# Epoch 4/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.8699 - auc_5: 0.9460 - loss: 0.3287 - precision_5: 0.8926 - recall_5: 0.8425 - val_accuracy: 0.8820 - val_auc_5: 0.9533 - val_loss: 0.3055 - val_precision_5: 0.9275 - val_recall_5: 0.8284 - learning_rate: 0.0010
# Epoch 5/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.8838 - auc_5: 0.9582 - loss: 0.2823 - precision_5: 0.9109 - recall_5: 0.8552 - val_accuracy: 0.9033 - val_auc_5: 0.9725 - val_loss: 0.2577 - val_precision_5: 0.9748 - val_recall_5: 0.8278 - learning_rate: 0.0010
# Epoch 6/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.8806 - auc_5: 0.9550 - loss: 0.2854 - precision_5: 0.9057 - recall_5: 0.8489 - val_accuracy: 0.8900 - val_auc_5: 0.9707 - val_loss: 0.2996 - val_precision_5: 0.8501 - val_recall_5: 0.9466 - learning_rate: 0.0010
# Epoch 7/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.8975 - auc_5: 0.9630 - loss: 0.2575 - precision_5: 0.9230 - recall_5: 0.8690 - val_accuracy: 0.9130 - val_auc_5: 0.9706 - val_loss: 0.2352 - val_precision_5: 0.9257 - val_recall_5: 0.8979 - learning_rate: 0.0010
# Epoch 8/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.8956 - auc_5: 0.9636 - loss: 0.2570 - precision_5: 0.9137 - recall_5: 0.8771 - val_accuracy: 0.7830 - val_auc_5: 0.9681 - val_loss: 0.4310 - val_precision_5: 0.9965 - val_recall_5: 0.5674 - learning_rate: 0.0010
# Epoch 9/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.8955 - auc_5: 0.9639 - loss: 0.2494 - precision_5: 0.9209 - recall_5: 0.8677 - val_accuracy: 0.8647 - val_auc_5: 0.9724 - val_loss: 0.3025 - val_precision_5: 0.9892 - val_recall_5: 0.7370 - learning_rate: 0.0010
# Epoch 10/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9018 - auc_5: 0.9672 - loss: 0.2398 - precision_5: 0.9237 - recall_5: 0.8787 - val_accuracy: 0.9120 - val_auc_5: 0.9750 - val_loss: 0.2367 - val_precision_5: 0.8925 - val_recall_5: 0.9366 - learning_rate: 0.0010
# Epoch 11/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9102 - auc_5: 0.9710 - loss: 0.2214 - precision_5: 0.9305 - recall_5: 0.8870 - val_accuracy: 0.9117 - val_auc_5: 0.9730 - val_loss: 0.2495 - val_precision_5: 0.8975 - val_recall_5: 0.9292 - learning_rate: 0.0010
# Epoch 12/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9018 - auc_5: 0.9672 - loss: 0.2366 - precision_5: 0.9229 - recall_5: 0.8795
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9018 - auc_5: 0.9672 - loss: 0.2366 - precision_5: 0.9229 - recall_5: 0.8795 - val_accuracy: 0.9140 - val_auc_5: 0.9726 - val_loss: 0.2400 - val_precision_5: 0.9111 - val_recall_5: 0.9172 - learning_rate: 0.0010
# Epoch 13/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9171 - auc_5: 0.9749 - loss: 0.2078 - precision_5: 0.9369 - recall_5: 0.8973 - val_accuracy: 0.9183 - val_auc_5: 0.9760 - val_loss: 0.2127 - val_precision_5: 0.9163 - val_recall_5: 0.9206 - learning_rate: 5.0000e-04
# Epoch 14/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9105 - auc_5: 0.9720 - loss: 0.2170 - precision_5: 0.9294 - recall_5: 0.8883 - val_accuracy: 0.8860 - val_auc_5: 0.9752 - val_loss: 0.2737 - val_precision_5: 0.8372 - val_recall_5: 0.9579 - learning_rate: 5.0000e-04
# Epoch 15/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9132 - auc_5: 0.9758 - loss: 0.2030 - precision_5: 0.9304 - recall_5: 0.8934 - val_accuracy: 0.9167 - val_auc_5: 0.9733 - val_loss: 0.2226 - val_precision_5: 0.9256 - val_recall_5: 0.9059 - learning_rate: 5.0000e-04
# Epoch 16/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9096 - auc_5: 0.9735 - loss: 0.2118 - precision_5: 0.9291 - recall_5: 0.8870 - val_accuracy: 0.9137 - val_auc_5: 0.9755 - val_loss: 0.2161 - val_precision_5: 0.9558 - val_recall_5: 0.8672 - learning_rate: 5.0000e-04
# Epoch 17/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9187 - auc_5: 0.9741 - loss: 0.2109 - precision_5: 0.9339 - recall_5: 0.9019 - val_accuracy: 0.8840 - val_auc_5: 0.9725 - val_loss: 0.2923 - val_precision_5: 0.9840 - val_recall_5: 0.7804 - learning_rate: 5.0000e-04
# Epoch 18/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9220 - auc_5: 0.9783 - loss: 0.1916 - precision_5: 0.9391 - recall_5: 0.9053
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9220 - auc_5: 0.9783 - loss: 0.1916 - precision_5: 0.9391 - recall_5: 0.9053 - val_accuracy: 0.8980 - val_auc_5: 0.9736 - val_loss: 0.2673 - val_precision_5: 0.8569 - val_recall_5: 0.9553 - learning_rate: 5.0000e-04
# Epoch 19/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9144 - auc_5: 0.9753 - loss: 0.2037 - precision_5: 0.9323 - recall_5: 0.8972 - val_accuracy: 0.9223 - val_auc_5: 0.9770 - val_loss: 0.2058 - val_precision_5: 0.9277 - val_recall_5: 0.9159 - learning_rate: 2.5000e-04
# Epoch 20/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9243 - auc_5: 0.9790 - loss: 0.1878 - precision_5: 0.9376 - recall_5: 0.9098 - val_accuracy: 0.9220 - val_auc_5: 0.9764 - val_loss: 0.2058 - val_precision_5: 0.9432 - val_recall_5: 0.8979 - learning_rate: 2.5000e-04
# Epoch 21/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9183 - auc_5: 0.9775 - loss: 0.1944 - precision_5: 0.9327 - recall_5: 0.9012 - val_accuracy: 0.9127 - val_auc_5: 0.9734 - val_loss: 0.2305 - val_precision_5: 0.9034 - val_recall_5: 0.9239 - learning_rate: 2.5000e-04
# Epoch 22/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9251 - auc_5: 0.9791 - loss: 0.1869 - precision_5: 0.9434 - recall_5: 0.9062 - val_accuracy: 0.9120 - val_auc_5: 0.9735 - val_loss: 0.2275 - val_precision_5: 0.9043 - val_recall_5: 0.9212 - learning_rate: 2.5000e-04
# Epoch 23/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9235 - auc_5: 0.9789 - loss: 0.1874 - precision_5: 0.9401 - recall_5: 0.9057 - val_accuracy: 0.8547 - val_auc_5: 0.9744 - val_loss: 0.3436 - val_precision_5: 0.7855 - val_recall_5: 0.9753 - learning_rate: 2.5000e-04
# Epoch 24/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9200 - auc_5: 0.9776 - loss: 0.1977 - precision_5: 0.9295 - recall_5: 0.9078
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9200 - auc_5: 0.9776 - loss: 0.1977 - precision_5: 0.9295 - recall_5: 0.9078 - val_accuracy: 0.9110 - val_auc_5: 0.9724 - val_loss: 0.2348 - val_precision_5: 0.9031 - val_recall_5: 0.9206 - learning_rate: 2.5000e-04
# Epoch 25/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9281 - auc_5: 0.9810 - loss: 0.1801 - precision_5: 0.9418 - recall_5: 0.9126 - val_accuracy: 0.9163 - val_auc_5: 0.9767 - val_loss: 0.2110 - val_precision_5: 0.9121 - val_recall_5: 0.9212 - learning_rate: 1.2500e-04
# Epoch 26/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9240 - auc_5: 0.9793 - loss: 0.1864 - precision_5: 0.9386 - recall_5: 0.9076 - val_accuracy: 0.9150 - val_auc_5: 0.9758 - val_loss: 0.2146 - val_precision_5: 0.9520 - val_recall_5: 0.8738 - learning_rate: 1.2500e-04
# Epoch 27/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9266 - auc_5: 0.9797 - loss: 0.1846 - precision_5: 0.9447 - recall_5: 0.9076 - val_accuracy: 0.9147 - val_auc_5: 0.9752 - val_loss: 0.2221 - val_precision_5: 0.9059 - val_recall_5: 0.9252 - learning_rate: 1.2500e-04
# Epoch 28/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9235 - auc_5: 0.9782 - loss: 0.1911 - precision_5: 0.9388 - recall_5: 0.9071 - val_accuracy: 0.9197 - val_auc_5: 0.9775 - val_loss: 0.2032 - val_precision_5: 0.9232 - val_recall_5: 0.9152 - learning_rate: 1.2500e-04
# Epoch 29/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9318 - auc_5: 0.9815 - loss: 0.1764 - precision_5: 0.9430 - recall_5: 0.9193 - val_accuracy: 0.9210 - val_auc_5: 0.9777 - val_loss: 0.2017 - val_precision_5: 0.9316 - val_recall_5: 0.9085 - learning_rate: 1.2500e-04
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.

# %%
from tensorflow.keras.models import load_model
from keras.saving import register_keras_serializable

@register_keras_serializable()
def channel_avg(x):
    return tf.reduce_mean(x, axis=3, keepdims=True)

@register_keras_serializable()
def channel_max(x):
    return tf.reduce_max(x, axis=3, keepdims=True)

@register_keras_serializable()
def output_shape(input_shape):
    return (input_shape[0], input_shape[1], input_shape[2], 1)

model = load_model(
    f"{models_path}/{model_name}.keras",
    custom_objects={
        "channel_avg": channel_avg,
        "channel_max": channel_max,
        "output_shape": output_shape
    }
)
# model = load_model(f"{models_path}/2Img_Tab.keras")


model.evaluate(X_test, y_test)

# Predicciones del modelo:
y_pred_probs = model.predict(X_test)
y_pred_labels = list(map(lambda x: 0 if x <= 0.5 else 1, y_pred_probs))

from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_labels, target_names=["Estrellas","Galaxias"]))

import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_labels)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=["Estrellas","Galaxias"], yticklabels=["Estrellas","Galaxias"], cmap='Blues', cbar=False, annot_kws={'size': 30})
plt.xlabel('Predichos')
plt.ylabel('Reales')
plt.title('Datos Tabulares & Imágenes Originales & Imágenes Fourier')
plt.show()

df_pred = pd.DataFrame(X_test[2],columns=df_all.columns.drop("label"))
df_pred["y_true"] = y_test
df_pred["y_pred"] = y_pred_labels

df_wrong = df_pred[df_pred["y_true"] != df_pred["y_pred"]]
df_well = df_pred[df_pred["y_true"] == df_pred["y_pred"]]

display(df_wrong.groupby(["y_true","y_pred"]).mean())
display(df_well.groupby(["y_true","y_pred"]).mean())

imgs_wrong = X_test[0][df_wrong.index]
imgs_processed_wrong = X_test[1][df_wrong.index]

print(df_wrong.index[:3])

# Crear figura y ejes
fig, axs = plt.subplots(3, 2, figsize=(12, 6))

# Iterar y mostrar cada imagen
for i, ax in enumerate(axs.flat):
    if i%2 == 0:
        ax.imshow(imgs_wrong[int(i/2)])
    else:
        ax.imshow(imgs_processed_wrong[int((i-1)/2)])
    ax.set_title(f'Imagen {i+1}')
    ax.axis('off')  # Ocultar ejes
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9239 - auc_5: 0.9743 - loss: 0.2014 - precision_5: 0.9318 - recall_5: 0.9075
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
#               precision    recall  f1-score   support
#
#    Estrellas       0.91      0.92      0.92      1527
#     Galaxias       0.92      0.91      0.91      1473
#
#     accuracy                           0.92      3000
#    macro avg       0.92      0.91      0.91      3000
# weighted avg       0.92      0.92      0.91      3000
#                psfMag_u  psfMag_g  psfMag_r  psfMag_i  psfMag_z  modelMag_u  \
# y_true y_pred
# 0      1       0.738894  0.736258  0.688499  0.676380  0.767016    0.612987
# 1      0       0.755284  0.762598  0.708392  0.699939  0.774460    0.636259
#
#                modelMag_g  modelMag_r  modelMag_i  modelMag_z  modelFlux_u  \
# y_true y_pred
# 0      1         0.624512    0.652925    0.433242    0.541500     0.013600
# 1      0         0.653281    0.677650    0.455335    0.556292     0.013348
#
#                modelFlux_g  modelFlux_r  modelFlux_i  modelFlux_z
# y_true y_pred
# 0      1          0.001201     0.000802     0.051340     0.018160
# 1      0          0.001172     0.000720     0.051096     0.018002
#                psfMag_u  psfMag_g  psfMag_r  psfMag_i  psfMag_z  modelMag_u  \
# y_true y_pred
# 0      0       0.661725  0.617697  0.568806  0.550667  0.622527    0.552852
# 1      1       0.710824  0.708512  0.662758  0.651853  0.731038    0.567320
#
#                modelMag_g  modelMag_r  modelMag_i  modelMag_z  modelFlux_u  \
# y_true y_pred
# 0      0         0.532033    0.551014    0.359249    0.446758     0.022949
# 1      1         0.573164    0.592781    0.393868    0.494068     0.014596
#
#                modelFlux_g  modelFlux_r  modelFlux_i  modelFlux_z
# y_true y_pred
# 0      0          0.015929     0.020282     0.070668     0.031769
# 1      1          0.002403     0.002720     0.053403     0.019689
# Index([6, 9, 31], dtype='int64')

# %%
perm[train_per + valid_per + 0:]
# Out:
# array([17515,  6802, 11536, ...,  2693,  8076,  7624])

# %%
# Mostrar imagen con matplotlib
plt.imshow(X_test[0][0])
# plt.imshow(X_test[1][498])
plt.axis('off')  # Opcional: quita los ejes
plt.show()
